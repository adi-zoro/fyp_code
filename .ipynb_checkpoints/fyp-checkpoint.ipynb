# %%
import os
path = "/Users/adi/Documents/University/YEAR 4/FYP thesis/Panonut360/dataset/"

# %%
import pandas as pd
import os

def load_all_data(base_dir):
    """
    Loads and consolidates data from multiple CSV files into a single DataFrame.
    
    Parameters:
        base_dir (str): The base directory containing subdirectories for each video, 
                        with CSV files for each user.
    
    Returns:
        DataFrame: A consolidated DataFrame containing data from all videos and users.
    """
    # Define an empty list to collect data from each CSV file
    all_data = []
    
    # Loop through each video directory
    for video_id in range(13, 14):  # Assuming video IDs are numbered from 1 to 15
        video_dir = os.path.join(base_dir, f"video_{video_id}")
        
        # Loop through each user's CSV file within the video directory
        for user_id in range(1, 2):  # Assuming user IDs are numbered from 1 to 50
            file_path = os.path.join(video_dir, f"user{user_id}.csv")

        
            
            # Check if the file exists to avoid errors
            if os.path.isfile(file_path):
                # Load the CSV file and handle the PlayerTime parsing
                df = pd.read_csv(file_path)

                df['video_ID'] = video_id
                df['user_ID'] = user_id
                
                # Ensure PlayerTime column has the correct format by trimming whitespace
                df['player_time'] = df['player_time'].str.strip()
                
                # Convert PlayerTime to datetime format
                try:
                    df['player_time'] = pd.to_timedelta(df['player_time'])
                    # df['player_time'] = pd.to_datetime(df['player_time'], format='%H:%M:%S.%f').dt.time
                except ValueError as e:
                    print(f"Error parsing time in file {file_path}: {e}")
                    continue  # Skip this file if there’s an error

                # Calculate elapsed time
                df['Elapsed_Time'] = (df['player_time'] - df['player_time'].iloc[0]).dt.total_seconds()
                
                
                # Append the processed DataFrame to the list
                all_data.append(df)
    
    # Concatenate all data into a single DataFrame
    consolidated_df = pd.concat(all_data, ignore_index=True)
    
    return consolidated_df

# %%
consolidated_data = load_all_data(path)

# %%
consolidated_data['frame']
# Out:
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
#          ...
# 21609    6163
# 21610    6163
# 21611    6163
# 21612    6164
# 21613    6164
# Name: frame, Length: 21614, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
features1 = ['head_x', 'head_y', 'head_z', 'eye_c_x', 'eye_c_y', 'eye_c_z', 'eye_x_t', 'eye_y_t', 'eye_z_t', 
            'head_pitch', 'head_yaw', 'head_roll', 'head_quaternion_w', 'head_quaternion_x', 
            'head_quaternion_y', 'head_quaternion_z', 'eye_quaternion_w', 'eye_quaternion_x', 
            'eye_quaternion_y', 'eye_quaternion_z']
features = ['frame','head_pitch', 'head_yaw', 'head_roll', 'eye_x_t', 'eye_y_t', 'eye_z_t']

co_matrix=consolidated_data[features].corr()
plt.figure(figsize=(5,5))
sns.heatmap(co_matrix, square=True, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ConvLSTM2D, Conv3D
from tensorflow.keras.layers import TimeDistributed, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import RMSprop

# Load your data into a DataFrame
# Assuming df is already defined with your columns.
# df = pd.read_csv('path_to_your_file.csv')  # Uncomment if loading from a file

# Normalize the head and eye movement columns
features = ['head_pitch', 'head_yaw', 'head_roll','eye_x_t', 'eye_y_t', 'eye_z_t']

df = consolidated_data[:]
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# Define input (X) and output (y) sequences
sequence_length = 5  # Length of each sequence
def create_sequences(df, features, sequence_length):
    X, y = [], []
    for i in range(len(df) - sequence_length):
        X.append(df[features].iloc[i:i + sequence_length].values)
        y.append(df[features].iloc[i + sequence_length].values)
    return np.array(X), np.array(y)

X, y = create_sequences(df, features, sequence_length)

# Reshape X for ConvLSTM: (samples, time steps, rows, columns, channels)
X = X.reshape((X.shape[0], sequence_length, 1, len(features), 1))
y = y.reshape((y.shape[0], 1, len(features)))

# Split data into train and test sets (80-20 split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# Build the ConvLSTM model
model = Sequential([
    ConvLSTM2D(filters=64, kernel_size=(1,3), padding="same", return_sequences=True, 
               input_shape=(sequence_length, 1, len(features), 1)),
    Dropout(0.5),
    # ConvLSTM2D(filters=64, kernel_size=(1, 3), padding="same", return_sequences=True),
    # Dropout(0.6),
    ConvLSTM2D(filters=32, kernel_size=(1,3), padding="same", return_sequences=False),
    Dropout(0.5),
    
    Flatten(),
    
    Dense(128, activation='relu'),  
    Dense(y.shape[-1])
])

# model.compile(optimizer=Adam(learning_rate=0.003, decay=1e-6), loss='mse')
model.compile(optimizer=RMSprop(learning_rate=0.001), loss='mse')

# Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=1, validation_split=0.1, 
                    callbacks=[early_stopping, reduce_lr])
# Evaluate the model
loss = model.evaluate(X_test, y_test)
print("Test Loss:", loss)

# Predicting on the test set
predictions = model.predict(X_test)

# Inverse transform to get the original scale for comparison
predictions = scaler.inverse_transform(predictions.reshape(-1, y.shape[-1]))
y_test_original = scaler.inverse_transform(y_test.reshape(-1, y.shape[-1]))

# Display some results
#print("Sample Predictions:", predictions[:5])
#print("Actual Values:", y_test_original[:5])
# Out:
# Epoch 1/50
# /Users/adi/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 87s 6ms/step - loss: 0.0140 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 2/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 89s 6ms/step - loss: 0.0041 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 3/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 90s 6ms/step - loss: 0.0033 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 4/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 90s 6ms/step - loss: 0.0032 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 5/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 89s 6ms/step - loss: 0.0029 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 6/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 88s 6ms/step - loss: 0.0031 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 7/50
# 15555/15558 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 90s 6ms/step - loss: 0.0029 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 8/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 94s 6ms/step - loss: 0.0027 - val_loss: 0.0031 - learning_rate: 5.0000e-04
# Epoch 9/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 92s 6ms/step - loss: 0.0027 - val_loss: 0.0031 - learning_rate: 5.0000e-04
# Epoch 10/50
# 15556/15558 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 91s 6ms/step - loss: 0.0027 - val_loss: 0.0032 - learning_rate: 5.0000e-04
# Epoch 11/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 92s 6ms/step - loss: 0.0025 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 12/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 91s 6ms/step - loss: 0.0026 - val_loss: 0.0031 - learning_rate: 2.5000e-04
# Epoch 13/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 93s 6ms/step - loss: 0.0026 - val_loss: 0.0030 - learning_rate: 2.5000e-04
# Epoch 14/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 92s 6ms/step - loss: 0.0027 - val_loss: 0.0031 - learning_rate: 2.5000e-04
# Epoch 15/50
# 15555/15558 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 94s 6ms/step - loss: 0.0027 - val_loss: 0.0030 - learning_rate: 2.5000e-04
# Epoch 16/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 139s 9ms/step - loss: 0.0026 - val_loss: 0.0030 - learning_rate: 1.2500e-04
# Epoch 17/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 135s 9ms/step - loss: 0.0025 - val_loss: 0.0030 - learning_rate: 1.2500e-04
# Epoch 18/50
# 15555/15558 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 135s 9ms/step - loss: 0.0025 - val_loss: 0.0030 - learning_rate: 1.2500e-04
# Epoch 19/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 134s 9ms/step - loss: 0.0027 - val_loss: 0.0030 - learning_rate: 6.2500e-05
# Epoch 20/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 142s 9ms/step - loss: 0.0024 - val_loss: 0.0030 - learning_rate: 6.2500e-05
# Epoch 21/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 139s 9ms/step - loss: 0.0028 - val_loss: 0.0030 - learning_rate: 6.2500e-05
# Epoch 22/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 136s 9ms/step - loss: 0.0027 - val_loss: 0.0030 - learning_rate: 3.1250e-05
# Epoch 23/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 136s 9ms/step - loss: 0.0023 - val_loss: 0.0030 - learning_rate: 3.1250e-05
# Epoch 24/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 137s 9ms/step - loss: 0.0027 - val_loss: 0.0030 - learning_rate: 3.1250e-05
# Epoch 25/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 133s 9ms/step - loss: 0.0025 - val_loss: 0.0030 - learning_rate: 1.5625e-05
# Epoch 26/50
# 15558/15558 ━━━━━━━━━━━━━━━━━━━━ 129s 8ms/step - loss: 0.0025 - val_loss: 0.0030 - learning_rate: 1.5625e-05
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1484
# Test Loss: 0.15111389756202698
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test_original,predictions)
print(r_score)
fit_accuracy = r_score * 100
print(f"Fit Accuracy (R² as percentage): {fit_accuracy:.2f}%")
# Out:
# 0.9500542147311393
# Fit Accuracy (R² as percentage): 95.01%

# %%
np.set_printoptions(formatter={'float_kind':'{:f}'.format})
pred = pd.DataFrame(predictions, columns =['head_pitch', 'head_yaw', 'head_roll','eye_x_t', 'eye_y_t', 'eye_z_t'])
orig = pd.DataFrame(y_test_original, columns =['head_pitch', 'head_yaw', 'head_roll','eye_x_t', 'eye_y_t', 'eye_z_t']) 
print(pred[:5])
print(orig[:5])
df
# print("Actual Values:", y_test_original[:5])
# Out:
#    head_pitch  head_yaw  head_roll   eye_x_t   eye_y_t   eye_z_t
# 0    0.952437  0.572860   0.011472  0.356230  0.735742  0.260603
# 1    0.977205  0.340114   0.016178  0.727466  0.631955  0.317792
# 2    0.981800  0.452903   0.012096  0.585124  0.630380  0.217350
# 3    0.989251  0.456838   0.011728  0.577475  0.594982  0.215005
# 4    0.022030  0.246229   0.012458  0.771799  0.529583  0.500503
#    head_pitch  head_yaw  head_roll   eye_x_t   eye_y_t   eye_z_t
# 0    0.952884  0.583205   0.010435  0.372178  0.754180  0.247239
# 1    0.991779  0.354085   0.020084  0.730871  0.622483  0.322756
# 2    0.987550  0.464075   0.003409  0.585760  0.631503  0.217442
# 3    0.987850  0.460590   0.004844  0.569323  0.590164  0.214819
# 4    0.003168  0.251355   0.014284  0.782596  0.538054  0.494389
#                  player_time  frame    head_x    head_y    head_z   eye_c_x  \
# 0     0 days 00:00:00.026000      0 -0.684901  0.217076 -0.695550  0.134552
# 1     0 days 00:00:00.039000      0 -0.702065  0.214013 -0.679193  0.130066
# 2     0 days 00:00:00.049000      0 -0.710593  0.212296 -0.670811  0.132584
# 3     0 days 00:00:00.071000      1 -0.727327  0.209134 -0.653650  0.127502
# 4     0 days 00:00:00.081000      1 -0.735753  0.207692 -0.644617  0.120392
# ...                      ...    ...       ...       ...       ...       ...
# 21609 0 days 00:03:25.680000   6163 -0.968014  0.069379  0.241111 -0.103775
# 21610 0 days 00:03:25.689000   6163 -0.969409  0.069347  0.235449 -0.100220
# 21611 0 days 00:03:25.698000   6163 -0.969409  0.069347  0.235449 -0.102829
# 21612 0 days 00:03:25.708000   6164 -0.970951  0.069503  0.228962 -0.103943
# 21613 0 days 00:03:25.721000   6164 -0.970951  0.069503  0.228962 -0.102844
#
#         eye_c_y   eye_c_z   eye_x_t   eye_y_t  ...  head_quaternion_x  \
# 0     -0.169449  0.976303  0.266427  0.671961  ...           0.113594
# 1     -0.161499  0.978256  0.263681  0.670076  ...           0.112602
# 2     -0.157776  0.978531  0.262728  0.672457  ...           0.111974
# 3     -0.158218  0.979126  0.258547  0.672618  ...           0.110740
# 4     -0.153732  0.980743  0.257356  0.671407  ...           0.110019
# ...         ...       ...       ...       ...  ...                ...
# 21609 -0.252396  0.962036  0.219775  0.558688  ...           0.045878
# 21610 -0.255295  0.961639  0.219519  0.558005  ...           0.045917
# 21611 -0.252487  0.962112  0.219519  0.558005  ...           0.045917
# 21612 -0.246841  0.963455  0.219285  0.558039  ...           0.046146
# 21613 -0.244385  0.964203  0.219285  0.558039  ...           0.046146
#
#        head_quaternion_y  head_quaternion_z  eye_quaternion_w  \
# 0               0.913713           0.071095         -0.455297
# 1               0.909350           0.068818         -0.462431
# 2               0.907120           0.067638         -0.465189
# 3               0.902531           0.065434         -0.476659
# 4               0.900114           0.064453         -0.479889
# ...                  ...                ...               ...
# 21609           0.614280          -0.002362          0.756635
# 21610           0.616577          -0.002294          0.754006
# 21611           0.616577          -0.002294          0.754006
# 21612           0.619184          -0.002296          0.752195
# 21613           0.619184          -0.002296          0.752195
#
#        eye_quaternion_x  eye_quaternion_y  eye_quaternion_z  video_ID  \
# 0              0.015945          0.889652          0.031157        13
# 1              0.015194          0.886047          0.029113        13
# 2              0.016557          0.884496          0.031481        13
# 3              0.017053          0.878361          0.031424        13
# 4              0.016501          0.876656          0.030144        13
# ...                 ...               ...               ...       ...
# 21609          0.072270         -0.646887          0.061787        13
# 21610          0.072624         -0.649833          0.062591        13
# 21611          0.072624         -0.649833          0.062591        13
# 21612          0.072420         -0.651934          0.062767        13
# 21613          0.072420         -0.651934          0.062767        13
#
#        user_ID  Elapsed_Time
# 0            1         0.000
# 1            1         0.013
# 2            1         0.023
# 3            1         0.045
# 4            1         0.055
# ...        ...           ...
# 21609        1       205.654
# 21610        1       205.663
# 21611        1       205.672
# 21612        1       205.682
# 21613        1       205.695
#
# [21614 rows x 25 columns]

# %% [markdown]
# different parameters
# <i><ul>
# - seq length : 5, activation: relu, epcohs: 200, batch size: 32, learningR: 0.001 = 5.03%
# - seq length : 5, activation: relu, epcohs: 50, batch size: 8,  learningR: 0.001  = 20.96%
# - seq length : 5, activation: relu, epcohs: 50, batch size: 4,  learningR: 0.001  = 39.96%
# - seq length : 5, activation: relu, epcohs: 50, batch size: 4,  learningR: 0.003 = 42.43%
# -  seq length : 5, activation: relu, epcohs: 50, batch size: 3,  learningR: 0.003 = 49%
# -  seq length : 5, activation: relu, epcohs: 50, batch size: 3,  learningR: 0.003 , dropoutLayers(0.3)= 52%
# - seq length : 5, activation: relu, epcohs: 50, batch size: 3,  learningR: 0.003 , dropoutLayers(0.5)= 54%
# -  seq length : 5, activation: relu, epcohs: 50, batch size: 2,  learningR: 0.003 , dropoutLayers(0.4)= 63.9%
# -  seq length : 5, activation: relu, epcohs: 50, batch size: 2,  learningR: 0.003 , dropoutLayers(0.5)= 67%
# - seq length : 5, activation: relu, epcohs: 50, batch size: 2,  learningR: 0.003 , dropoutLayers(0.5), LR Scheduler (patience:3) = 69.7%
# -  seq length : 5, activation: relu, epcohs: 50, batch size: 2,  learningR: 0.005 , dropoutLayers(0.5), LR Scheduler (patience:3) = 92.37%
# <ul></i>

# %%
from sklearn.metrics import mean_squared_error
dense_mse1 = mean_squared_error(y_test_original, predictions)
print(f"Model MSE = {dense_mse1:.4f}")
# Out:
# Model MSE = 0.0028

# %%
import matplotlib.pyplot as plt

# Extract loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training vs validation loss
plt.figure(figsize=(10, 6))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
